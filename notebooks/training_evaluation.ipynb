# %% [markdown]
# # Training & Evaluation (Part 3)
# Notebook for running the baseline CNN and recording metrics.
#
# Place dataset (GTSRB) path in `DATA_DIR` and run cells. The default path is `gtsrb/Train`, which matches the extracted local dataset layout.

# %%
# Hyperparameters and paths
import os
DATA_DIR = os.environ.get('GTSRB_DIR', 'gtsrb/Train')  # override via env var
MODEL_OUT = 'reports/artifacts/gtsrb_model.keras'

print('DATA_DIR =', DATA_DIR)

# Example: reuse existing entrypoint
# from src.part3_ml.train import main  # runs full pipeline
# main()

# Current final metrics are generated by src/evaluation/run_evaluation.py.
# To run training directly, use:
#   python src/train.py gtsrb/Train reports/artifacts/gtsrb_model.keras
