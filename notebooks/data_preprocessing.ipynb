# %% [markdown]
# # Data Preprocessing (Part 2)
# This notebook is a starter for `Femi` to implement data loading and preprocessing steps.
#
# Tasks:
# - Load raw data from `data/raw/`
# - Implement cleaning and transforms
# - Save sample outputs to `data/processed/`
#
# Notes:
# - Keep transformations deterministic (set seeds)
# - Document assumptions in Markdown cells

# %%
# Imports
import os
from pathlib import Path

ROOT = Path('..').resolve()
RAW_DIR = ROOT / 'data' / 'raw'
OUT_DIR = ROOT / 'data' / 'processed'
OUT_DIR.mkdir(parents=True, exist_ok=True)

print('Raw dir:', RAW_DIR)
print('Out dir :', OUT_DIR)

# TODO: implement load functions and examples below
# Example placeholder:
# df = load_some_csv(RAW_DIR / 'example.csv')
# df_clean = your_cleaning_pipeline(df)
# df_clean.to_csv(OUT_DIR / 'example_clean.csv', index=False)
